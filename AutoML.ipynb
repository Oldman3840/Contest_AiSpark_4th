# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('./dataset/train_data.csv')
test_data = pd.read_csv('./dataset/test_data.csv')

# %%
train_data['HP'] = np.nan
for n in train_data['type'].value_counts().keys():
    
    if n == 0 or n == 4 or n == 5 or n == 6 or n == 7:
        train_data.loc[train_data['type'] == n, 'HP'] = 'HP30'
        test_data.loc[test_data['type'] == n, 'HP'] = 'HP30'
    elif n == 1:
        train_data.loc[train_data['type'] == n, 'HP'] = 'HP20'
        test_data.loc[test_data['type'] == n, 'HP'] = 'HP20'
    elif n == 2:
        train_data.loc[train_data['type'] == n, 'HP'] = 'HP10'
        test_data.loc[test_data['type'] == n, 'HP'] = 'HP10'
    else:
        train_data.loc[train_data['type'] == n, 'HP'] = 'HP50'
        test_data.loc[test_data['type'] == n, 'HP'] = 'HP50'

# train_data['HP'] = train_data['HP'].astype('int64')
# test_data['HP'] = test_data['HP'].astype('int64')

train_data
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           1.59         41.00           0.7          20.53     1680.0
# 1           2.97         59.28           0.7          38.40     3142.0
# 2           1.91         45.29           0.7          24.73     2023.0
# 3           2.37         51.33           0.7          30.63     2506.0
# 4           1.90         45.21           0.7          24.65     2017.0
# ...          ...           ...           ...            ...        ...
# 2458        2.28         50.20           0.7          29.53     2416.0
# 2459        2.04         46.94           0.7          26.34     2155.0
# 2460        1.19         35.74           0.7          15.39     1259.0
# 2461        1.21         36.00           0.7          15.64     1280.0
# 2462        2.72         55.99           0.7          35.19     2879.0
#
#       motor_temp  motor_vibe  type    HP
# 0          58.67        2.93     0  HP30
# ...

# %%
train_data.drop('type', axis=1, inplace=True)
test_data.drop('type', axis=1, inplace=True)

# %%
from pycaret.classification import *

# %%
exp_class = setup(data=train_data, target='HP', session_id=42, normalize=True)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# ...

# %%
best = compare_models(include=['lightgbm', 'rf', 'mlp', 'knn'], sort='F1')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              01:00:59
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Exception ignored in: <function FastMemory.__del__ at 0x00000247A81DC700>
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\ex_data\lib\site-packages\pycaret\internal\memory.py", line 458, in __del__
#     self.reduce_size()
#   File "c:\Users\User\anaconda3\envs\ex_data\lib\site-packages\pycaret\internal\memory.py", line 444, in reduce_size
#     return super().reduce_size()
#   File "c:\Users\User\anaconda3\envs\ex_data\lib\site-packages\joblib\memory.py", line 999, in reduce_size
#     self.store_backend.reduce_store_size(self.bytes_limit)
#   File "c:\Users\User\anaconda3\envs\ex_data\lib\site-packages\joblib\_store_backends.py", line 281, in reduce_store_size
#     items_to_delete = self._get_items_to_delete(bytes_limit)
# ...
